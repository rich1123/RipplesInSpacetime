# %% [markdown]
# ## Part 1: Given an int, repeatedly add its digits until the result is one digit.
#
# * [Constraints](#Constraints)
# * [Test Cases](#Test-Cases)
# * [Algorithm](#Algorithm)
# * [Code](#Code)
# * [Unit Test](#Unit-Test)
# * [Solution Notebook](#Solution-Notebook)

# %% [markdown]
# ## Constraints
#
# * Can we assume num is not negative?
#     * Yes
# * Can we assume the inputs are valid?
#     * No
# * Can we assume this fits memory?
#     * Yes

# %% [markdown]
# ## Test Cases
#
# <pre>
# * None input -> TypeError
# * negative input -> ValueError
# * 9 -> 9
# * 138 -> 3
# * 65536 -> 7
# </pre>

# %% [markdown]
# ## Algorithm
#
# The naive solution simply isolates each digit with with modulo and integer division. We'll add each isolated digit to a list and sum the values.
#
# - 138 % 10 = 8 -> isolated
# - 138 // 10 = 13
# - 13 % 10 = 3 -> isolated
# - 13 // 10 = 1
# - 1 % 10 = 1 -> isolated
# A more optimal solution exists, by recognizing this is a digital root. See the Wikipedia article for more information.
#
# Complexity:
#
# Time: O(1)
# Space: O(1)

# %% [markdown]
# ## Code

# %%
class Solution(object):

    def add_digits(self, val):
        # TODO: Implement me
        return ((val - 1) % 9 - 1) if val else 0
        # print(val)

# %% [markdown]
# ## Unit Test

# %% [markdown]
# **The following unit test is expected to fail until you solve the challenge.**

# %%
# %load test_add_digits.py
from nose.tools import assert_equal, assert_raises


class TestAddDigits(object):

    def test_add_digits(self, func):
        assert_raises(TypeError, func, None)
        assert_raises(ValueError, func, -1)
        assert_equal(func(0), 0)
        assert_equal(func(9), 9)
        assert_equal(func(45), 9)
        assert_equal(func(36), 9)
        assert_equal(func(63), 9)
        assert_equal(func(72), 9)
        assert_equal(func(41), 5)
        assert_equal(func(138), 3)
        assert_equal(func(65536), 7) 
        assert_equal(func(444), 3) 
        print('Success: test_add_digits')


def main():
    test = TestAddDigits()
    solution = Solution()
    test.test_add_digits(solution.add_digits)
    try:
        test.test_add_digits(solution.add_digits_optimized)
    except AttributeError:
        # Alternate solutions are only defined
        # in the solutions file
        pass


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-e0732887cfd7> in <module>()
#      33
#      34 if __name__ == '__main__':
# ---> 35     main()
#
# <ipython-input-20-e0732887cfd7> in main()
#      23     test = TestAddDigits()
#      24     solution = Solution()
# ---> 25     test.test_add_digits(solution.add_digits)
#      26     try:
#      27         test.test_add_digits(solution.add_digits_optimized)
#
# <ipython-input-20-e0732887cfd7> in test_add_digits(self, func)
#       5
#       6     def test_add_digits(self, func):
# ----> 7         assert_raises(TypeError, func, None)
#       8         assert_raises(ValueError, func, -1)
#       9         assert_equal(func(0), 0)
#
# /usr/lib/python3.6/unittest/case.py in assertRaises(self, expected_exception, *args, **kwargs)
#     731         context = _AssertRaisesContext(expected_exception, self)
#     732         try:
# --> 733             return context.handle('assertRaises', args, kwargs)
#     734         finally:
#     735             # bpo-23890: manually break a reference cycle
#
# /usr/lib/python3.6/unittest/case.py in handle(self, name, args, kwargs)
#     176                 self.obj_name = str(callable_obj)
#     177             with self:
# --> 178                 callable_obj(*args, **kwargs)
#     179         finally:
#     180             # bpo-23890: manually break a reference cycle
#
# /usr/lib/python3.6/unittest/case.py in __exit__(self, exc_type, exc_value, tb)
#     199             if self.obj_name:
#     200                 self._raiseFailure("{} not raised by {}".format(exc_name,
# --> 201                                                                 self.obj_name))
#     202             else:
#     203                 self._raiseFailure("{} not raised".format(exc_name))
#
# /usr/lib/python3.6/unittest/case.py in _raiseFailure(self, standardMsg)
#     133     def _raiseFailure(self, standardMsg):
#     134         msg = self.test_case._formatMessage(self.msg, standardMsg)
# --> 135         raise self.test_case.failureException(msg)
#     136
#     137 class _AssertRaisesBaseContext(_BaseTestCaseContext):
#
# AssertionError: TypeError not raised by add_digits

# %%
# You may need to do this
# !pip install nose
# Out:
# Collecting nose
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 5.2MB/s
# Installing collected packages: nose
# Successfully installed nose-1.3.7
