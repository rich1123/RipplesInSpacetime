# %% [markdown]
# ## Part3: Create a class with an insert method to insert an int to a list.  It should also support calculating the max, min, mean, and mode in O(1).
#
# * [Constraints](#Constraints)
# * [Test Cases](#Test-Cases)
# * [Algorithm](#Algorithm)
# * [Code](#Code)
# * [Unit Test](#Unit-Test)
# * [Solution Notebook](#Solution-Notebook)

# %% [markdown]
# ## Constraints
#
# * Can we assume the inputs are valid?
#     * No
# * Is there a range of inputs?
#     * 0 <= item <= 100
# * Should mean return a float?
#     * Yes
# * Should the other results return an int?
#     * Yes
# * If there are multiple modes, what do we return?
#     * Any of the modes
# * Can we assume this fits memory?
#     * Yes

# %% [markdown]
# ## Test Cases
#
# * None -> TypeError
# * [] -> ValueError
# * [5, 2, 7, 9, 9, 2, 9, 4, 3, 3, 2]
#     * max: 9
#     * min: 2
#     * mean: 55
#     * mode: 9 or 2

# %% [markdown]
# ## Algorithm
#
# We'll init our max and min to None. Alternatively, we can init them to -sys.maxsize and sys.maxsize, respectively.
# - For mean, we'll keep track of the number of items we have inserted so far, as well as the running sum.
# - For mode, we'll keep track of the current mode and an array with the size of the given upper limit
# - Each element in the array will be init to 0
# - Each time we insert, we'll increment the element corresponding to the inserted item's value
# On each insert:
# - Update the max and min
# - Update the mean by calculating running_sum / num_items
# - Update the mode by comparing the mode array's value with the current mode

# %% [markdown]
# ## Code

# %%
class Solution(object):

    def __init__(self, upper_limit=100):
        # TODO: Implement me
        self.li = []

    def insert(self, val):
        # TODO: Implement me
        li.insert(0, val)
        return li 
    
    def min(self): 
        # TODO: Implement me
        #  for val in l:
           return min(li)
    
    def max(self):
        # TODO: Implement me
        # for val in l:
           return max(li)

    def mean(self, l):
        # TODO: Implement me
        mean = (sum(li.values()) / len(li))
        return mean

    
    def mode(self, val):
        # TODO: Implement me
        pass
        return mode

# %% [markdown]
# ## Unit Test

# %% [markdown]
# **The following unit test is expected to fail until you solve the challenge.**

# %%
# %load test_math_ops.py
from nose.tools import assert_equal, assert_true, assert_raises


class TestMathOps(object):

    def test_math_ops(self):
        solution = Solution()
        assert_raises(TypeError, solution.insert, None)
        solution.insert(5)
        solution.insert(2)
        solution.insert(7)
        solution.insert(9)
        solution.insert(9)
        solution.insert(2)
        solution.insert(9)
        solution.insert(4)
        solution.insert(3)
        solution.insert(3)
        solution.insert(2)
        assert_equal(solution.max, 9)
        assert_equal(solution.min, 2)
        assert_equal(solution.mean, 5)
        assert_true(solution.mode in (2, 9))
        print('Success: test_math_ops')


def main():
    test = TestMathOps()
    test.test_math_ops()


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b08da557a8dc> in <module>()
#      31
#      32 if __name__ == '__main__':
# ---> 33     main()
#
# <ipython-input-15-b08da557a8dc> in main()
#      27 def main():
#      28     test = TestMathOps()
# ---> 29     test.test_math_ops()
#      30
#      31
#
# <ipython-input-15-b08da557a8dc> in test_math_ops(self)
#       6     def test_math_ops(self):
#       7         solution = Solution()
# ----> 8         assert_raises(TypeError, solution.insert, None)
#       9         solution.insert(5)
#      10         solution.insert(2)
#
# /usr/lib/python3.6/unittest/case.py in assertRaises(self, expected_exception, *args, **kwargs)
#     731         context = _AssertRaisesContext(expected_exception, self)
#     732         try:
# --> 733             return context.handle('assertRaises', args, kwargs)
#     734         finally:
#     735             # bpo-23890: manually break a reference cycle
#
# /usr/lib/python3.6/unittest/case.py in handle(self, name, args, kwargs)
#     176                 self.obj_name = str(callable_obj)
#     177             with self:
# --> 178                 callable_obj(*args, **kwargs)
#     179         finally:
#     180             # bpo-23890: manually break a reference cycle
#
# <ipython-input-14-c845c44bfbd0> in insert(***failed resolving arguments***)
#       7     def insert(self, val):
#       8         # TODO: Implement me
# ----> 9         li.insert(0, val)
#      10         return li
#      11
#
# NameError: name 'li' is not defined

# %%
pip install nose
# Out:
# Collecting nose
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 4.7MB/s
# Installing collected packages: nose
# Successfully installed nose-1.3.7
